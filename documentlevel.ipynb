# %%
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
import os
import pickle

html_files_directory = 'C:/Users/Jahnavi/Desktop/Judgment DataComp/Judgment Data/judgments'
output_directory = 'output_vectors_documents'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Loop through each HTML file in the specified directory
for filename in os.listdir(html_files_directory):
    if filename.endswith(".html"):
        file_path = os.path.join(html_files_directory, filename)

        # Read the HTML content
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()

        # Parse HTML using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extract paragraphs
        paragraphs = soup.find_all('p')

        # Create a list to store paragraphs and their IDs
        paragraphs_with_ids = []

        for index, paragraph in enumerate(paragraphs, start=1):
            paragraph_text = paragraph.get_text(strip=True)
            paragraphs_with_ids.append((f'p_{index}', paragraph_text))

        # Create TF-IDF vectorizer
        vectorizer = TfidfVectorizer(stop_words = 'english')

        # Extract paragraphs and IDs from the list
        paragraph_ids, paragraph_texts = zip(*paragraphs_with_ids)

        # Create TF-IDF matrix
        tfidf_matrix = vectorizer.fit_transform(paragraph_texts)
        tfidf_array=tfidf_matrix.toarray()
        # Save the TF-IDF matrix using pickle
        output_file_path = os.path.join(output_directory, f'{os.path.splitext(filename)[0]}_tfidf.pkl')
        with open(output_file_path, 'wb') as output_file:
            pickle.dump(tfidf_array, output_file)

        print(f'TF-IDF vectors for {filename} saved to {output_file_path}')
# Out:
# TF-IDF vectors for 1000008.html saved to output_vectors_documents\1000008_tfidf.pkl
# TF-IDF vectors for 1000049.html saved to output_vectors_documents\1000049_tfidf.pkl
# TF-IDF vectors for 1000086.html saved to output_vectors_documents\1000086_tfidf.pkl
# TF-IDF vectors for 1000097.html saved to output_vectors_documents\1000097_tfidf.pkl
# TF-IDF vectors for 1000126.html saved to output_vectors_documents\1000126_tfidf.pkl
# TF-IDF vectors for 1000139.html saved to output_vectors_documents\1000139_tfidf.pkl
# TF-IDF vectors for 1000149.html saved to output_vectors_documents\1000149_tfidf.pkl
# TF-IDF vectors for 1000162.html saved to output_vectors_documents\1000162_tfidf.pkl
# TF-IDF vectors for 1000218.html saved to output_vectors_documents\1000218_tfidf.pkl
# TF-IDF vectors for 1000294.html saved to output_vectors_documents\1000294_tfidf.pkl
# TF-IDF vectors for 100040791.html saved to output_vectors_documents\100040791_tfidf.pkl
# ...

# %%
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer
import os
import pickle

html_files_directory = 'C:/Users/Jahnavi/Desktop/Judgment DataComp/Judgment Data/judgments'
output_directory = 'output_vectors_documents'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Loop through each HTML file in the specified directory
for filename in os.listdir(html_files_directory):
    if filename.endswith(".html"):
        file_path = os.path.join(html_files_directory, filename)

        # Read the HTML content
        with open(file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()

        # Parse HTML using BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Extract paragraphs
        paragraphs = soup.find_all('p')

        # Print the number of paragraphs found
        # ...

# Create a list to store paragraphs and their IDs
        paragraphs_with_ids = []

        for index, paragraph in enumerate(paragraphs, start=1):
            paragraph_text = paragraph.get_text(strip=True)
            paragraphs_with_ids.append((f'p_{index}', paragraph_text))

# Check if there are paragraphs before proceeding
        if not paragraphs_with_ids:
            print(f'No paragraphs found in {filename}. Skipping...')
            continue

# Create TF-IDF vectorizer
        vectorizer = TfidfVectorizer()

# Extract paragraphs and IDs from the list
        paragraph_ids, paragraph_texts = zip(*paragraphs_with_ids)

# Create TF-IDF matrix
        tfidf_matrix = vectorizer.fit_transform(paragraph_texts)
        tfidf_array = tfidf_matrix.toarray()

# Save the TF-IDF matrix using pickle
        output_file_path = os.path.join(output_directory, f'{os.path.splitext(filename)[0]}_tfidf.pkl')
        with open(output_file_path, 'wb') as output_file:
            pickle.dump(tfidf_array, output_file)

        print(f'TF-IDF vectors for {filename} saved to {output_file_path}')
# Out:
# TF-IDF vectors for 1000008.html saved to output_vectors_documents\1000008_tfidf.pkl
# TF-IDF vectors for 1000049.html saved to output_vectors_documents\1000049_tfidf.pkl
# TF-IDF vectors for 1000086.html saved to output_vectors_documents\1000086_tfidf.pkl
# TF-IDF vectors for 1000097.html saved to output_vectors_documents\1000097_tfidf.pkl
# TF-IDF vectors for 1000126.html saved to output_vectors_documents\1000126_tfidf.pkl
# TF-IDF vectors for 1000139.html saved to output_vectors_documents\1000139_tfidf.pkl
# TF-IDF vectors for 1000149.html saved to output_vectors_documents\1000149_tfidf.pkl
# TF-IDF vectors for 1000162.html saved to output_vectors_documents\1000162_tfidf.pkl
# TF-IDF vectors for 1000218.html saved to output_vectors_documents\1000218_tfidf.pkl
# TF-IDF vectors for 1000294.html saved to output_vectors_documents\1000294_tfidf.pkl
# TF-IDF vectors for 100040791.html saved to output_vectors_documents\100040791_tfidf.pkl
# ...
